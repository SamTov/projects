# %%
# Linalg libraries
import numpy as np

# Plotting libraries
import matplotlib.pyplot as plt

# %%
background = np.genfromtxt(
    "./data/sample_bg_morestat.csv", delimiter=",", skip_header=1
    )
sample = np.genfromtxt(
    "./data/sample_mH500_morestat.csv", delimiter=",", skip_header=1
    )

# %%
plt.plot(sample[:,0], sample[:, 2], '.', label="Background")
