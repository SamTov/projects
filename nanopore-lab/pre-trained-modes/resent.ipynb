# %%
from transformers import AutoImageProcessor, ResNetForImageClassification
import torch
from datasets import load_dataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from transformers import AutoImageProcessor, ResNetForImageClassification
#       2 import torch
# ----> 3 from datasets import load_dataset
#
# ImportError: cannot import name 'load_dataset' from 'datasets' (unknown location)

# %%
! pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 1.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (0.15.1)
# Requirement already satisfied: pandas in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (2.28.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (6.0)
# Requirement already satisfied: packaging in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (4.62.3)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-macosx_10_9_x86_64.whl (35 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 2.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pyarrow>=8.0.0
#   Downloading pyarrow-12.0.1-cp310-cp310-macosx_10_14_x86_64.whl (24.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 583.3 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (2023.3.0)
# Requirement already satisfied: numpy>=1.17 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from datasets) (1.23.5)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-macosx_10_9_x86_64.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.1/358.1 kB 2.8 MB/s eta 0:00:003.4 MB/s eta 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-macosx_10_9_x86_64.whl (29 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 524.2 kB/s eta 0:00:00 kB/s eta 0:00:0101
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-macosx_10_9_x86_64.whl (35 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: filelock in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/samueltovey/miniconda3/envs/zincware/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, pyarrow, multidict, frozenlist, dill, async-timeout, yarl, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.13.1 dill-0.3.6 frozenlist-1.3.3 multidict-6.0.4 multiprocess-0.70.14 pyarrow-12.0.1 xxhash-3.2.0 yarl-1.9.2
