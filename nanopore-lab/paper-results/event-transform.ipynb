# %%
import numpy as np

import matplotlib.pyplot as plt

from ssqueezepy import ssq_cwt

import pickle as pk

# %%
with open("/work/jhossbach/Raw_Dataset/dataset_all/test/24607.pk", "rb") as f:
    data = pk.load(f)

# %%
squeezed, img, *_ = ssq_cwt(
                data[0], scales="log-piecewise", wavelet=("gmw", {"dtype": "float32"}), fs=1e6
            )

# %%
plt.imshow(np.abs(img))
