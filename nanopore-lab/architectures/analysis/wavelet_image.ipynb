# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = "/data/jhossbach/Image_Dataset/dataset_all/train/169603.pk"
event_path = "/data/jhossbach/Image_Dataset/dataset_all/train/events/169603.pk"

# %%
data = np.load(data_path, allow_pickle=True)

# %%
plt.imshow(np.linalg.norm(data[1], axis=0))
