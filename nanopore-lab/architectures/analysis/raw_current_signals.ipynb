# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
root_dir = "/data/jhossbach/Peptide_events/L2AS4.pk"

# %%
data = np.load(root_dir, allow_pickle=True)

# %%
plt.plot(data[4])
plt.xlabel("Time")
plt.ylabel("Current")
plt.savefig("current-trace.pdf", dpi=600)
plt.show()
