# %%
import h5py as hf
import matplotlib.pyplot as plt

# %%
data= hf.File("trajectory.hdf5")["colloids"]["Unwrapped_Positions"][:]

# %%
plt.plot(data[:, :, 0], data[:, :, 1])
plt.plot(data[-1, :, 0], data[-1, :, 1], 'ko')
