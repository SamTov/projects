# %%
import jax.numpy as np
from jax.nn.initializers import Initializer
import flax.linen as nn

# %%
class StochasticOscillatorNetwork:
    """
    Class to implement the stochastic oscillator.
    """
    def __init__(self, flax_module: nn.Module, samples: int):
        """
        Constructor for the oscillator network.
        
        Parameters
        ----------
        flax_module : nn.Module
            Module to replicate in the samples.
        samples : int
            Number of models to use in the computation.
        """
        self._base_module = flax_module
        self.samples = samples
