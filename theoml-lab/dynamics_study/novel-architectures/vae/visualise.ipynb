# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
entropy = np.load("entropy.npy", allow_pickle=True)
trace = np.load("traces.npy", allow_pickle=True)
loss = np.load("losses.npy", allow_pickle=True)

# %%
plt.plot(loss, trace[:, 0], '.')
plt.gca().invert_xaxis()
plt.show()

# %%
plt.errorbar(np.linspace(0, 200, 200), entropy[:, 0], yerr=entropy[:, 1])

# %%
plt.errorbar( np.linspace(0, 200, 200), trace[:, 0], yerr=trace[:, 1])
