# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
entropy = np.load("entropy.npy")
trace = np.load("traces.npy")
loss = np.load("losses.npy", allow_pickle=True)

# %%
losses = [item["loss"] for item in loss]

# %%
plt.plot(losses, entropy[:, 0], '.')
plt.gca().invert_xaxis()

# %%
plt.plot(losses, trace[:, 0], '.')
plt.gca().invert_xaxis()
